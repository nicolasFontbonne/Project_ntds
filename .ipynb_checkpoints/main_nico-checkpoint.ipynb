# %% [markdown]
# # Nicolas

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from scipy import sparse
import scipy.sparse.linalg
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

# %%
routes = pd.read_csv('data/routes.dat', sep=',', encoding='utf-8')
routes.columns = ['Airline','AirlineID','SourceAirport','SourceAirportID','DestinationAirport','DestinationAirportID','Codeshare','Stops','Equipment']
routes.head()
# Out:
#   Airline AirlineID SourceAirport SourceAirportID DestinationAirport  \
# 0      2B       410           ASF            2966                KZN
# 1      2B       410           ASF            2966                MRV
# 2      2B       410           CEK            2968                KZN
# 3      2B       410           CEK            2968                OVB
# 4      2B       410           DME            4029                KZN
#
#   DestinationAirportID Codeshare  Stops Equipment
# 0                 2990       NaN      0       CR2
# 1                 2962       NaN      0       CR2
# 2                 2990       NaN      0       CR2
# 3                 4078       NaN      0       CR2
# 4                 2990       NaN      0       CR2

# %%
airlines = pd.read_csv('data/airlines.dat', sep=',', encoding='utf-8')
airlines.columns = ['Airline ID', 'Name', 'City',  'IATA', 'ICAO','Callsign','Country','Active']
airlines.head()
# Out:
#    Airline ID                                          Name City IATA ICAO  \
# 0           1                                Private flight   \N    -  NaN
# 1           2                                   135 Airways   \N  NaN  GNL
# 2           3                                 1Time Airline   \N   1T  RNX
# 3           4  2 Sqn No 1 Elementary Flying Training School   \N  NaN  WYT
# 4           5                               213 Flight Unit   \N  NaN  TFU
#
#   Callsign         Country Active
# 0      NaN             NaN      Y
# 1  GENERAL   United States      N
# 2  NEXTIME    South Africa      Y
# 3      NaN  United Kingdom      N
# 4      NaN          Russia      N

# %%
airports = pd.read_csv('data/airports.dat', sep=',', encoding='utf-8')
airports.columns = ['Airport ID', 'Name', 'City', 'Country',  'IATA', 'ICAO','Callsign',,'Active','Timezone','DST', 'Tz database time zone', 'Type', 'Source']
airports.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-cdf2e2993af2> in <module>()
#       1 airports = pd.read_csv('data/airports.dat', sep=',', encoding='utf-8')
# ----> 2 airports.columns = ['Airport ID', 'Name', 'Alias', 'IATA', 'ICAO','Callsign','Country','Active','Timezone','DST', 'Tz database time zone', 'Type', 'Source']
#       3 airports.head()
#
# ~/anaconda3/envs/ntds_2018/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/anaconda3/envs/ntds_2018/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     644
#     645     def _set_axis(self, axis, labels):
# --> 646         self._data.set_axis(axis, labels)
#     647         self._clear_item_cache()
#     648
#
# ~/anaconda3/envs/ntds_2018/lib/python3.7/site-packages/pandas/core/internals.py in set_axis(self, axis, new_labels)
#    3321             raise ValueError(
#    3322                 'Length mismatch: Expected axis has {old} elements, new '
# -> 3323                 'values have {new} elements'.format(old=old_len, new=new_len))
#    3324
#    3325         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 14 elements, new values have 13 elements
